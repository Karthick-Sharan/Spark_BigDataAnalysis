# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Spark
# Out:
# /content/drive/MyDrive/Spark

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.0/spark-3.0.0-bin-hadoop3.2.tgz

# %%
# !tar xf spark-3.0.0-bin-hadoop3.2.tgz

# %%
# !pip install findspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/drive/MyDrive/Spark/spark-3.0.0-bin-hadoop3.2"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import *

spark = SparkSession.builder.getOrCreate()
from pyspark.sql.functions import trim, to_date, year, month

# %%
from pyspark import SparkContext

sc=SparkContext.getOrCreate()

# %%
spark = SparkSession.builder \
    .master("local") \
    .appName("Word Count") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
df = spark.read.format('csv').option("header",True).load('find_text.csv')

# %%
df.show(5)
# Out:
# +--------------------+----+
# |              id_str|text|
# +--------------------+----+
# |'793270689780203520'|null|
# |'793281386912354304'|null|
# |'793299404975247360'|null|
# |'793301295255945216'|null|
# |'793315815411978240'|null|
# +--------------------+----+
# only showing top 5 rows

# %%
df=spark.read.format("csv").option("multiLine", True).option("header", True).option("escape", "\"").load("Amazon_Responded_Oct05.csv") #Loading Amazon_response file on to spark

# %%
df.show() #displaying top 20 rows
# Out:
# +--------------------+--------------------+----------------+-----------+-------------------+---------------------+--------------+-----------------+--------------+--------------------+-------------+-------------+--------------------+------------------+--------------------+--------------+--------------------+--------------+---------+-----------------------+-------------------------+-----------------------+-------------+---------+--------------------+
# |
# +--------------------+--------------------+----------------+-----------+-------------------+---------------------+--------------+-----------------+--------------+--------------------+-------------+-------------+--------------------+------------------+--------------------+--------------+--------------------+--------------+---------+-----------------------+-------------------------+-----------------------+-------------+---------+--------------------+
# |                null|            null|       null|               null|                 null|          null|             null|          null|                null|         null|         null|                null|              null|                null|          null|                null|          null|     null|                   null|                     null|                   null|         null|     null|                null|
# |
# |
# |'793501578766319616'|Tue Nov 01 17:14:...|     SeanEPanjab|  143515471|              51287|                 4079|         False|               74|         False|Content marketer;...|   غریب الوطن|        False|                1503|               850|Thu May 13 17:43:...|            en|@AmazonHelp It wa...|             0|    False|             AmazonHelp|     7.932813869123543...|               85741735|            0|    False|@AmazonHelp It wa...|
# |
# |'793502854459879424'|Tue Nov 01 17:19:...|      AmazonHelp|   85741735|            2225450|                11366|         False|              796|         False|We answer Amazon ...|         null|         True|              149569|                53|Wed Oct 28 04:17:...|            en|@SeanEPanjab Plea...|             0|    False|            SeanEPanjab|     7.935015787663196...|              143515471|            0|    False|@SeanEPanjab Plea...|
# |
# |
# |
# |'793513446633533440'|Tue Nov 01 18:02:...|      AmazonHelp|   85741735|            2225450|                11366|         False|              796|         False|We answer Amazon ...|         null|         True|              149569|                53|Wed Oct 28 04:17:...|            en|@SeanEPanjab I'm ...|             0|    False|            SeanEPanjab|     7.935118992792084...|              143515471|            0|    False|@SeanEPanjab I'm ...|
# |                null|            null|       null|               null|                 null|          null|             null|          null|                null|         null|         null|                null|              null|                null|          null|                null|          null|     null|                   null|                     null|                   null|         null|     null|                null|
# |
# |
# |
# |'793423313674571776'|Tue Nov 01 12:03:...|      AmazonHelp|   85741735|            2225442|                11366|         False|              796|         False|We answer Amazon ...|         null|         True|              149568|                53|Wed Oct 28 04:17:...|            en|@aakashwangnoo Hi...|             0|    False|          aakashwangnoo|     7.934074303443108...|               71457972|            0|    False|@aakashwangnoo Hi...|
# |
# |
# |'793492430666498050'|Tue Nov 01 16:38:...|      AmazonHelp|   85741735|            2225442|                11366|         False|              796|         False|We answer Amazon ...|         null|         True|              149568|                53|Wed Oct 28 04:17:...|            en|@aakashwangnoo Hi...|             0|    False|          aakashwangnoo|     7.93467086869631e+17|               71457972|            0|    False|@aakashwangnoo Hi...|
# |
# |
# +--------------------+--------------------+----------------+-----------+-------------------+---------------------+--------------+-----------------+--------------+--------------------+-------------+-------------+--------------------+------------------+--------------------+--------------+--------------------+--------------+---------+-----------------------+-------------------------+-----------------------+-------------+---------+--------------------+
# only showing top 20 rows

# %%
print("Total number of records:")
df.count()
# Out:
# Total number of records:
# 462030

# %%
###################################################################################################################################
# TASK 1 
###################################################################################################################################

#selecting required columns
df=df.select('id_str','tweet_created_at','user_verified','favorite_count','retweet_count','text_') 
df.show()
# Out:
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+
# |              id_str|    tweet_created_at|user_verified|favorite_count|retweet_count|               text_|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+
#

# +--------------------+--------------------+-------------+--------------+-------------+--------------------+
# only showing top 20 rows

# %%
## STEP 1 (Removing Records with "user_verified" = FALSE)

df_t = df_c.filter(df_c['user_verified']=='True')
print("Top 10 rows of new DF:")
df_t.show(10)
print("Total number of records which have 'user_verfied' as True : ", df_t.count())
# Out:
# Top 10 rows of new DF:
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+
# |              id_str|    tweet_created_at|user_verified|favorite_count|retweet_count|               text_|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+
# |'793281386912354304'|Tue Nov 01 02:39:...|         True|             0|            0|@SeanEPanjab I'm ...|
# |'793502854459879424'|Tue Nov 01 17:19:...|         True|             0|            0|@SeanEPanjab Plea...|
# |'793504235400884224'|Tue Nov 01 17:25:...|         True|             0|            0|@SeanEPanjab With...|
# |'793513446633533440'|Tue Nov 01 18:02:...|         True|             0|            0|@SeanEPanjab I'm ...|
# |'793301295255945216'|Tue Nov 01 03:59:...|         True|             0|            0|@aakashwangnoo Hi...|
# |'793423313674571776'|Tue Nov 01 12:03:...|         True|             0|            0|@aakashwangnoo Hi...|
# |'793423314333134850'|Tue Nov 01 12:03:...|         True|             0|            0|@aakashwangnoo Pl...|
# |'793492430666498050'|Tue Nov 01 16:38:...|         True|             0|            0|@aakashwangnoo Hi...|
# |'793551822476705793'|Tue Nov 01 20:34:...|         True|             0|            0|@aakashwangnoo He...|
# |'793551823147765765'|Tue Nov 01 20:34:...|         True|             0|            0|@aakashwangnoo at...|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+
# only showing top 10 rows
#
# Total number of records which have 'user_verfied' as True :  171899

# %%
## STEP 2 (Creating 'Date' column to perform grouping)

from pyspark.sql.functions import substring
from pyspark.sql.functions import trim

df_t=df_t.withColumn("date", substring(trim('tweet_created_at'),4,7)) #creating new columns using substring from 'tweet_created_at' column
df_t.show()
# Out:
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+
# |              id_str|    tweet_created_at|user_verified|favorite_count|retweet_count|               text_|   date|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+
# |'793281386912354304'|Tue Nov 01 02:39:...|         True|             0|            0|@SeanEPanjab I'm ...| Nov 01|
# |'793502854459879424'|Tue Nov 01 17:19:...|         True|             0|            0|@SeanEPanjab Plea...| Nov 01|
# |'793504235400884224'|Tue Nov 01 17:25:...|         True|             0|            0|@SeanEPanjab With...| Nov 01|
# |'793513446633533440'|Tue Nov 01 18:02:...|         True|             0|            0|@SeanEPanjab I'm ...| Nov 01|
# |'793301295255945216'|Tue Nov 01 03:59:...|         True|             0|            0|@aakashwangnoo Hi...| Nov 01|
# |'793423313674571776'|Tue Nov 01 12:03:...|         True|             0|            0|@aakashwangnoo Hi...| Nov 01|
# |'793423314333134850'|Tue Nov 01 12:03:...|         True|             0|            0|@aakashwangnoo Pl...| Nov 01|
# |'793492430666498050'|Tue Nov 01 16:38:...|         True|             0|            0|@aakashwangnoo Hi...| Nov 01|
# |'793551822476705793'|Tue Nov 01 20:34:...|         True|             0|            0|@aakashwangnoo He...| Nov 01|
# |'793551823147765765'|Tue Nov 01 20:34:...|         True|             0|            0|@aakashwangnoo at...| Nov 01|
# |'793676510494359552'|Wed Nov 02 04:50:...|         True|             0|            0|@aakashwangnoo So...| Nov 02|
# |'793322306848292864'|Tue Nov 01 05:22:...|         True|             0|            0|@Murtazansp Hello...| Nov 01|
# |'793322433625415680'|Tue Nov 01 05:23:...|         True|             0|            0|@Murtazansp Could...| Nov 01|
# |'793872301339148288'|Wed Nov 02 17:48:...|         True|             0|            0|@Murtazansp Hi, s...| Nov 02|
# |'793872423271661568'|Wed Nov 02 17:48:...|         True|             0|            0|@Murtazansp Pleas...| Nov 02|
# |'795207462160896001'|Sun Nov 06 10:13:...|         True|             0|            0|@Murtazansp Hey t...| Nov 06|
# |'793375905280393216'|Tue Nov 01 08:55:...|         True|             0|            0|@anchitkhar Hello...| Nov 01|
# |'793397280254472193'|Tue Nov 01 10:20:...|         True|             0|            0|@anchitkhar HI! W...| Nov 01|
# |'793534958073679872'|Tue Nov 01 19:27:...|         True|             0|            0|@anchitkhar Hey! ...| Nov 01|
# |'793378044052406272'|Tue Nov 01 09:04:...|         True|             0|            0|@imkapsicum Hey, ...| Nov 01|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+
# only showing top 20 rows

# %%
## STEP 2 (Counting no. tweets in each date by grouping)

#Grouping tweets by the newly created 'date' column
df_tweets_date=df_t.groupby('date').count()

#Sorting in descending order.
from pyspark.sql.functions import desc
df_tweets_date.orderBy(desc("count")).show()
# Out:
# +-------+-----+
# |   date|count|
# +-------+-----+
# | Jan 03| 1536|
# | Jan 10| 1508|
# | Jan 11| 1496|
# | Jan 12| 1410|
# | Jan 06| 1364|
# | Jan 07| 1360|
# | Jan 20| 1342|
# | Mar 02| 1298|
# | Jan 13| 1295|
# | Jan 21| 1292|
# | Jan 14| 1290|
# | Jan 18| 1286|
# | Dec 15| 1279|
# | Jan 24| 1259|
# | Nov 18| 1249|
# | Dec 03| 1201|
# | Jan 02| 1196|
# | Jun 27| 1192|
# | Jul 04| 1190|
# | Jan 19| 1175|
# +-------+-----+
# only showing top 20 rows

# %%
# We can observe that 'Jan 03' has the maximum no. tweets in a day, followed by Jan 10.

# %%
## STEP 3

# Creating new column to store sum of favorite and retweet for each tweets
from pyspark.sql.functions import expr
df_sum_count = df_t.withColumn('sum_favorite_retweet',expr("favorite_count+retweet_count"))
df_sum_count.show(5)
# Out:
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+--------------------+
# |              id_str|    tweet_created_at|user_verified|favorite_count|retweet_count|               text_|   date|sum_favorite_retweet|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+--------------------+
# |'793281386912354304'|Tue Nov 01 02:39:...|         True|             0|            0|@SeanEPanjab I'm ...| Nov 01|                 0.0|
# |'793502854459879424'|Tue Nov 01 17:19:...|         True|             0|            0|@SeanEPanjab Plea...| Nov 01|                 0.0|
# |'793504235400884224'|Tue Nov 01 17:25:...|         True|             0|            0|@SeanEPanjab With...| Nov 01|                 0.0|
# |'793513446633533440'|Tue Nov 01 18:02:...|         True|             0|            0|@SeanEPanjab I'm ...| Nov 01|                 0.0|
# |'793301295255945216'|Tue Nov 01 03:59:...|         True|             0|            0|@aakashwangnoo Hi...| Nov 01|                 0.0|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+--------------------+
# only showing top 5 rows

# %%
df_100 =df_sum_count.filter(trim(df_sum_count.date) =='Jan 03').orderBy(desc("sum_favorite_retweet")).limit(100)
df_100.show(10)
# Out:
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+--------------------+
# |              id_str|    tweet_created_at|user_verified|favorite_count|retweet_count|               text_|   date|sum_favorite_retweet|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+--------------------+
# |'816329761530093568'|Tue Jan 03 17:05:...|         True|             4|            1|@amazon worst sho...| Jan 03|                 5.0|
# |'816083406962434048'|Tue Jan 03 00:47:...|         True|             2|            1|@ItsJosshA We alw...| Jan 03|                 3.0|
# |'816086117938319360'|Tue Jan 03 00:57:...|         True|             2|            0|@ItsJosshA Oh no!...| Jan 03|                 2.0|
# |'816095108013654017'|Tue Jan 03 01:33:...|         True|             1|            1|@KStefl Sounds li...| Jan 03|                 2.0|
# |'816109446069911554'|Tue Jan 03 02:30:...|         True|             1|            1|@Schoey1992 Happy...| Jan 03|                 2.0|
# |'816157517428523008'|Tue Jan 03 05:41:...|         True|             1|            1|@ratbones666 You ...| Jan 03|                 2.0|
# |'816217909819297792'|Tue Jan 03 09:41:...|         True|             2|            0|@ThorpPerrow Awww...| Jan 03|                 2.0|
# |'816314295680110593'|Tue Jan 03 16:04:...|         True|             2|            0|@thedexterouz Hi!...| Jan 03|                 2.0|
# |'816090553595084800'|Tue Jan 03 01:15:...|         True|             1|            0|@matt_linsley Ple...| Jan 03|                 1.0|
# |'816165445925474304'|Tue Jan 03 06:13:...|         True|             1|            0|@VlSlT Sorry to h...| Jan 03|                 1.0|
# +--------------------+--------------------+-------------+--------------+-------------+--------------------+-------+--------------------+
# only showing top 10 rows

# %%
df_100.show(20,False) # to view full text
# Out:
# +--------------------+------------------------------+-------------+--------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+
# |id_str              |tweet_created_at              |user_verified|favorite_count|retweet_count|text_                                                                                                                                       |date   |sum_favorite_retweet|
# +--------------------+------------------------------+-------------+--------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+
# |'816329761530093568'|Tue Jan 03 17:05:56 +0000 2017|True         |4             |1            |@amazon worst shopping  experience,  no service, no substantial reply to complaints, no delivery for 1 week post guarantee date.            | Jan 03|5.0                 |
# |'816083406962434048'|Tue Jan 03 00:47:00 +0000 2017|True         |2             |1            |@ItsJosshA We always aim to deliver by the date given in your confirmation email. Have we missed that date? Any update in tracking?  ^NF    | Jan 03|3.0                 |
# |'816086117938319360'|Tue Jan 03 00:57:47 +0000 2017|True         |2             |0            |@ItsJosshA Oh no! I'm sorry! Please reach out to us so that we can look into options: https://t.co/hApLpMlfHN. ^JO                          | Jan 03|2.0                 |
# |'816095108013654017'|Tue Jan 03 01:33:30 +0000 2017|True         |1             |1            |@KStefl Sounds like you know what to add to your Halloween playlist for this year! ^BV                                                      | Jan 03|2.0                 |
# |'816109446069911554'|Tue Jan 03 02:30:29 +0000 2017|True         |1             |1            |@Schoey1992 Happy Birthday, Matt! #FriendsForever #FriendshipGoals ^JO                                                                      | Jan 03|2.0                 |
# |'816157517428523008'|Tue Jan 03 05:41:30 +0000 2017|True         |1             |1            |@ratbones666 You so fancy!!! You already knooow!!! ^EP                                                                                      | Jan 03|2.0                 |
# |'816217909819297792'|Tue Jan 03 09:41:28 +0000 2017|True         |2             |0            |@ThorpPerrow Awww! Happy Birthday, you don't look a day over 20 ;-) .Pass on your details here: https://t.co/g52MRb0AOt for lil surprise ^RS| Jan 03|2.0                 |
# |'816314295680110593'|Tue Jan 03 16:04:29 +0000 2017|True         |2             |0            |@thedexterouz Hi! We'd like to help. When you have a moment, please connect with us here:  https://t.co/vlvfJr4nN9 ^YP                      | Jan 03|2.0                 |
# |'816090553595084800'|Tue Jan 03 01:15:24 +0000 2017|True         |1             |0            |@matt_linsley Please keep us posted on this and let us know if it doesn't arrive tomorrow. ^BV                                              | Jan 03|1.0                 |
# |'816165445925474304'|Tue Jan 03 06:13:00 +0000 2017|True         |1             |0            |@VlSlT Sorry to hear that, contact us here: https://t.co/hApLpMlfHN and we'll look into it for you. ^AS                                     | Jan 03|1.0                 |
# |'816323706431668226'|Tue Jan 03 16:41:52 +0000 2017|True         |1             |0            |@PPramod2041984 Hi, apologies for the bad experience. Request you to return the incorrect item using the link provided above. ^SH           | Jan 03|1.0                 |
# |'816190084546498560'|Tue Jan 03 07:50:54 +0000 2017|True         |1             |0            |@mailstosandeep Hey, glad to know your issue has been resolved. Do keep us posted for any further concerns. ^CA                             | Jan 03|1.0                 |
# |'816072943495249921'|Tue Jan 03 00:05:26 +0000 2017|True         |1             |0            |@Elidan_8 Here's now to identify if the e-mail is from Amazon and how to report it if it's not: https://t.co/Zw0REzYrZU. ^CL                | Jan 03|1.0                 |
# |'816074813408165888'|Tue Jan 03 00:12:52 +0000 2017|True         |1             |0            |@joyfulneesh Thanks for the shout out! ^JO                                                                                                  | Jan 03|1.0                 |
# |'816077071801810944'|Tue Jan 03 00:21:50 +0000 2017|True         |1             |0            |@brooklynnnross I'm sorry that the wrong case was sent! Was the item being fulfilled by Amazon or a third-party seller on our site? ^JO     | Jan 03|1.0                 |
# |'816086664053456896'|Tue Jan 03 00:59:57 +0000 2017|True         |1             |0            |@DurhamBelle I'm sorry, they don't have a direct number. You can contact us here for an update: https://t.co/5D5BOLXLjp. ^AR                | Jan 03|1.0                 |
# |'816092970168549376'|Tue Jan 03 01:25:01 +0000 2017|True         |1             |0            |@heypardeep We're always looking to improve. Pls share your specific feedback via this form: https://t.co/z96J1aqgy4 ^SJ                    | Jan 03|1.0                 |
# |'816093471610195968'|Tue Jan 03 01:27:00 +0000 2017|True         |1             |0            |@__NaijaDrew Sorry for the delay. Did we indicate a new delivery date? Pls check e-mail for any order updates. ^SJ                          | Jan 03|1.0                 |
# |'816203796342833152'|Tue Jan 03 08:45:24 +0000 2017|True         |1             |0            |@magsophazjon Please contact us directly in the link below so we can have a further look into this: https://t.co/JzP7hlA23B ^PK             | Jan 03|1.0                 |
# |'816204084709654528'|Tue Jan 03 08:46:32 +0000 2017|True         |1             |0            |@magsophazjon Hey you need to download the Amazon Video app which is separate to your shopping app. ^RS                                     | Jan 03|1.0                 |
# +--------------------+------------------------------+-------------+--------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+
# only showing top 20 rows

# %%
# Cleaning text field

from pyspark.sql.functions import regexp_replace
from pyspark.sql.functions import lower

df_100=df_100.withColumn("text",regexp_replace('text_', '@[A-Za-z0-9_]+', ''))
df_100=df_100.withColumn("text",regexp_replace('text', '#[A-Za-z0-9_]+', ''))
df_100=df_100.withColumn("text",regexp_replace("text", "\'", ""))
df_100=df_100.withColumn("text",regexp_replace('text', 'http\S+', ''))
df_100=df_100.withColumn("text",regexp_replace('text', '[()!?]', ''))
df_100=df_100.withColumn("text",regexp_replace('text', '\[.*?\]', ''))
df_100=df_100.withColumn("text",regexp_replace('text', '[$#,:^.;-]', ''))

df_100=df_100.withColumn("text",regexp_replace("text", "[^A-Za-z0-9 ]+", ""))

# %%
df_100.show(10,False)
# Out:
# +--------------------+------------------------------+-------------+--------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+--------------------------------------------------------------------------------------------------------------------------+
# |id_str              |tweet_created_at              |user_verified|favorite_count|retweet_count|text_                                                                                                                                       |date   |sum_favorite_retweet|text                                                                                                                      |
# +--------------------+------------------------------+-------------+--------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+--------------------------------------------------------------------------------------------------------------------------+
# |'816329761530093568'|Tue Jan 03 17:05:56 +0000 2017|True         |4             |1            |@amazon worst shopping  experience,  no service, no substantial reply to complaints, no delivery for 1 week post guarantee date.            | Jan 03|5.0                 | worst shopping  experience  no service no substantial reply to complaints no delivery for 1 week post guarantee date     |
# |'816083406962434048'|Tue Jan 03 00:47:00 +0000 2017|True         |2             |1            |@ItsJosshA We always aim to deliver by the date given in your confirmation email. Have we missed that date? Any update in tracking?  ^NF    | Jan 03|3.0                 | We always aim to deliver by the date given in your confirmation email Have we missed that date Any update in tracking  NF|
# |'816086117938319360'|Tue Jan 03 00:57:47 +0000 2017|True         |2             |0            |@ItsJosshA Oh no! I'm sorry! Please reach out to us so that we can look into options: https://t.co/hApLpMlfHN. ^JO                          | Jan 03|2.0                 | Oh no Im sorry Please reach out to us so that we can look into options  JO                                               |
# |'816095108013654017'|Tue Jan 03 01:33:30 +0000 2017|True         |1             |1            |@KStefl Sounds like you know what to add to your Halloween playlist for this year! ^BV                                                      | Jan 03|2.0                 | Sounds like you know what to add to your Halloween playlist for this year BV                                             |
# |'816109446069911554'|Tue Jan 03 02:30:29 +0000 2017|True         |1             |1            |@Schoey1992 Happy Birthday, Matt! #FriendsForever #FriendshipGoals ^JO                                                                      | Jan 03|2.0                 | Happy Birthday Matt   JO                                                                                                 |
# |'816157517428523008'|Tue Jan 03 05:41:30 +0000 2017|True         |1             |1            |@ratbones666 You so fancy!!! You already knooow!!! ^EP                                                                                      | Jan 03|2.0                 | You so fancy You already knooow EP                                                                                       |
# |'816217909819297792'|Tue Jan 03 09:41:28 +0000 2017|True         |2             |0            |@ThorpPerrow Awww! Happy Birthday, you don't look a day over 20 ;-) .Pass on your details here: https://t.co/g52MRb0AOt for lil surprise ^RS| Jan 03|2.0                 | Awww Happy Birthday you dont look a day over 20  Pass on your details here  for lil surprise RS                          |
# |'816314295680110593'|Tue Jan 03 16:04:29 +0000 2017|True         |2             |0            |@thedexterouz Hi! We'd like to help. When you have a moment, please connect with us here:  https://t.co/vlvfJr4nN9 ^YP                      | Jan 03|2.0                 | Hi Wed like to help When you have a moment please connect with us here   YP                                              |
# |'816090553595084800'|Tue Jan 03 01:15:24 +0000 2017|True         |1             |0            |@matt_linsley Please keep us posted on this and let us know if it doesn't arrive tomorrow. ^BV                                              | Jan 03|1.0                 | Please keep us posted on this and let us know if it doesnt arrive tomorrow BV                                            |
# |'816165445925474304'|Tue Jan 03 06:13:00 +0000 2017|True         |1             |0            |@VlSlT Sorry to hear that, contact us here: https://t.co/hApLpMlfHN and we'll look into it for you. ^AS                                     | Jan 03|1.0                 | Sorry to hear that contact us here  and well look into it for you AS                                                     |
# +--------------------+------------------------------+-------------+--------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+--------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
# Text field after cleaning

df_100=df_100.select('date','sum_favorite_retweet',lower('text').alias('text'))
df_100.show(20,False)
# Out:
# +-------+--------------------+--------------------------------------------------------------------------------------------------------------------------+
# |date   |sum_favorite_retweet|text                                                                                                                      |
# +-------+--------------------+--------------------------------------------------------------------------------------------------------------------------+
# | Jan 03|5.0                 | worst shopping  experience  no service no substantial reply to complaints no delivery for 1 week post guarantee date     |
# | Jan 03|3.0                 | we always aim to deliver by the date given in your confirmation email have we missed that date any update in tracking  nf|
# | Jan 03|2.0                 | oh no im sorry please reach out to us so that we can look into options  jo                                               |
# | Jan 03|2.0                 | sounds like you know what to add to your halloween playlist for this year bv                                             |
# | Jan 03|2.0                 | happy birthday matt   jo                                                                                                 |
# | Jan 03|2.0                 | you so fancy you already knooow ep                                                                                       |
# | Jan 03|2.0                 | awww happy birthday you dont look a day over 20  pass on your details here  for lil surprise rs                          |
# | Jan 03|2.0                 | hi wed like to help when you have a moment please connect with us here   yp                                              |
# | Jan 03|1.0                 | please keep us posted on this and let us know if it doesnt arrive tomorrow bv                                            |
# | Jan 03|1.0                 | sorry to hear that contact us here  and well look into it for you as                                                     |
# | Jan 03|1.0                 | hi apologies for the bad experience request you to return the incorrect item using the link provided above sh            |
# | Jan 03|1.0                 | hey glad to know your issue has been resolved do keep us posted for any further concerns ca                              |
# | Jan 03|1.0                 | heres now to identify if the email is from amazon and how to report it if its not  cl                                    |
# | Jan 03|1.0                 | thanks for the shout out jo                                                                                              |
# | Jan 03|1.0                 | im sorry that the wrong case was sent was the item being fulfilled by amazon or a thirdparty seller on our site jo       |
# | Jan 03|1.0                 | im sorry they dont have a direct number you can contact us here for an update  ar                                        |
# | Jan 03|1.0                 | were always looking to improve pls share your specific feedback via this form  sj                                        |
# | Jan 03|1.0                 | sorry for the delay did we indicate a new delivery date pls check email for any order updates sj                         |
# | Jan 03|1.0                 | please contact us directly in the link below so we can have a further look into this  pk                                 |
# | Jan 03|1.0                 | hey you need to download the amazon video app which is separate to your shopping app rs                                  |
# +-------+--------------------+--------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# Writting the text from top 100 tweet to .txt file

df_100.select('text').write.csv('Top_100',header=True)

# %%
from pathlib import Path

entries = Path('/content/drive/MyDrive/Spark/Top_100')
for entry in entries.iterdir():
    print(entry.name)
# Out:
# part-00000-83717e3e-53da-47fc-ab2e-78a8efddaaec-c000.csv
# .part-00000-83717e3e-53da-47fc-ab2e-78a8efddaaec-c000.csv.crc
# _SUCCESS
# ._SUCCESS.crc

# %%
# Counting frequency of words from the collected top 100 tweets

txt = sc.textFile("/content/drive/MyDrive/Spark/Top_100/part-00000-83717e3e-53da-47fc-ab2e-78a8efddaaec-c000.csv")
print(txt)
# Out:
# /content/drive/MyDrive/Spark/Top_100/part-00000-83717e3e-53da-47fc-ab2e-78a8efddaaec-c000.csv MapPartitionsRDD[466] at textFile at NativeMethodAccessorImpl.java:0

# %%
words = txt.flatMap(lambda line: line.split()).map(lambda word: (word, 1))
print(words)
# Out:
# PythonRDD[468] at RDD at PythonRDD.scala:53

# %%
for i in words.collect():
  print(i)
# Out:
# ('text', 1)
# ('worst', 1)
# ('shopping', 1)
# ('experience', 1)
# ('no', 1)
# ('service', 1)
# ('no', 1)
# ('substantial', 1)
# ('reply', 1)
# ('to', 1)
# ('complaints', 1)
# ('no', 1)
# ('delivery', 1)
# ('for', 1)
# ('1', 1)
# ('week', 1)
# ('post', 1)
# ('guarantee', 1)
# ('date', 1)
# ('we', 1)
# ('always', 1)
# ('aim', 1)
# ('to', 1)
# ('deliver', 1)
# ('by', 1)
# ('the', 1)
# ('date', 1)
# ('given', 1)
# ('patience', 1)
# ('hk', 1)

# %%
count = words.reduceByKey(lambda a, b: a + b)
print(count)
# Out:
# PythonRDD[473] at RDD at PythonRDD.scala:53

# %%
# getting count of words

word_count = count.collect()
word_count
# Out:
# [('worst', 1),
#  ('no', 5),
#  ('service', 1),
#  ('substantial', 1),
#  ('delivery', 6),
#  ('1', 1),
#  ('week', 1),
#  ('we', 23),
#  ('always', 3),
#  ('in', 12),
#  ('confirmation', 1),
#  ('have', 18),
#  ('update', 2),
#  ('tracking', 5),
#  ('oh', 1),
#  ('im', 13),
#  ('out', 6),
#  ('us', 28),
#  ('look', 7),
#  ('into', 6),
#  ('options', 3),
#  ('sounds', 1),
#  ('like', 7),
#  ('know', 13),
#  ('playlist', 1),
#  ('this', 27),
#  ('year', 2),
#  ('bv', 2),
#  ('matt', 1),
#  ('fancy', 1),
#  ('already', 1),
#  ('20', 1),
#  ('pass', 2),
#  ('details', 6),
#  ('lil', 1),
#  ('wed', 5),
#  ('help', 8),
#  ('when', 5),
#  ('connect', 1),
#  ('let', 7),
#  ('arrive', 6),
#  ('tomorrow', 2),
#  ('hear', 4),
#  ('as', 4),
#  ('apologies', 2),
#  ('incorrect', 1),
#  ('item', 5),
#  ('using', 2),
#  ('above', 2),
#  ('do', 4),
#  ('further', 5),
#  ('concerns', 1),
#  ('ca', 1),
#  ('heres', 1),
#  ('now', 3),
#  ('identify', 1),
#  ('is', 13),
#  ('amazon', 6),
#  ('thanks', 11),
#  ('shout', 1),
#  ('was', 5),
#  ('sent', 1),
#  ('fulfilled', 1),
#  ('site', 3),
#  ('an', 7),
#  ('ar', 3),
#  ('looking', 2),
#  ('improve', 1),
#  ('share', 1),
#  ('specific', 1),
#  ('feedback', 7),
#  ('via', 4),
#  ('form', 1),
#  ('sj', 6),
#  ('delay', 1),
#  ('indicate', 1),
#  ('new', 3),
#  ('check', 1),
#  ('updates', 3),
#  ('below', 1),
#  ('pk', 1),
#  ('end', 1),
#  ('of', 3),
#  ('est', 1),
#  ('at', 6),
#  ('checkout', 1),
#  ('late', 2),
#  ('af', 2),
#  ('feel', 4),
#  ('athena', 1),
#  ('rather', 2),
#  ('delivering', 2),
#  ('things', 1),
#  ('than', 1),
#  ('cold', 1),
#  ('medicine', 1),
#  ('am', 1),
#  ('card', 2),
#  ('typically', 2),
#  ('process', 1),
#  ('business', 2),
#  ('days', 1),
#  ('refund', 2),
#  ('requested', 2),
#  ('en', 2),
#  ('showing', 1),
#  ('flagging', 1),
#  ('reviewed', 1),
#  ('earliest', 1),
#  ('leave', 3),
#  ('account', 2),
#  ('but', 3),
#  ('youre', 2),
#  ('waiting', 1),
#  ('doug', 1),
#  ('returns', 1),
#  ('items', 1),
#  ('online', 1),
#  ('more', 3),
#  ('shipment', 1),
#  ('transit', 1),
#  ('destination', 1),
#  ('edd', 1),
#  ('promised', 1),
#  ('seeing', 1),
#  ('advise', 1),
#  ('forwarded', 1),
#  ('relevant', 1),
#  ('department', 2),
#  ('jj', 1),
#  ('there', 2),
#  ('getting', 2),
#  ('sound', 1),
#  ('right', 1),
#  ('support', 3),
#  ('availability', 1),
#  ('payment', 2),
#  ('truly', 2),
#  ('only', 1),
#  ('able', 3),
#  ('make', 2),
#  ('sure', 4),
#  ('33', 1),
#  ('regret', 1),
#  ('inconvenience', 2),
#  ('work', 1),
#  ('these', 4),
#  ('instances', 1),
#  ('never', 1),
#  ('happen', 1),
#  ('sr', 2),
#  ('enjoying', 2),
#  ('collection', 1),
#  ('keeps', 1),
#  ('receiver', 1),
#  ('stopped', 1),
#  ('working', 1),
#  ('very', 1),
#  ('interest', 2),
#  ('phone', 2),
#  ('longer', 1),
#  ('download13sr', 1),
#  ('visit', 2),
#  ('mobile', 1),
#  ('browser', 1),
#  ('where', 2),
#  ('newest', 1),
#  ('customer', 2),
#  ('i', 9),
#  ('understand', 1),
#  ('allow', 1),
#  ('free', 2),
#  ('chat', 1),
#  ('assistance', 1),
#  ('weve', 1),
#  ('connecting', 1),
#  ('team', 2),
#  ('send', 1),
#  ('use', 1),
#  ('desktop', 1),
#  ('cd', 1),
#  ('way', 2),
#  ('ab', 1),
#  ('concern', 1),
#  ('filled', 1),
#  ('mm', 1),
#  ('12', 2),
#  ('ask', 1),
#  ('are', 2),
#  ('quality', 1),
#  ('wan', 1),
#  ('22', 2),
#  ('shirt', 1),
#  ('contacted', 2),
#  ('them', 1),
#  ('ra', 1),
#  ('delighted', 1),
#  ('appreciation', 1),
#  ('following', 2),
#  ('carriers', 1),
#  ('until', 2),
#  ('8', 1),
#  ('friendly', 1),
#  ('love', 1),
#  ('certainly', 1),
#  ('try', 3),
#  ('danny', 1),
#  ('hb', 4),
#  ('may', 2),
#  ('caused', 1),
#  ('alerts', 2),
#  ('open', 1),
#  ('settings', 1),
#  ('kd', 1),
#  ('tm', 2),
#  ('john', 1),
#  ('trouble', 3),
#  ('tried', 1),
#  ('unlinkinglinking', 1),
#  ('cs', 1),
#  ('recommend', 1),
#  ('website', 1),
#  ('social', 1),
#  ('gl', 3),
#  ('confirm', 1),
#  ('questions', 2),
#  ('li', 1),
#  ('wyour', 1),
#  ('replacements', 1),
#  ('start', 1),
#  ('puppy', 1),
#  ('pretty', 1),
#  ('cute', 1),
#  ('sharing', 1),
#  ('becoming', 1),
#  ('joke', 1),
#  ('speak', 1),
#  ('trying', 1),
#  ('put', 1),
#  ('cutting', 1),
#  ('eligible', 1),
#  ('edit', 1),
#  ('orders', 1),
#  ('couriers', 1),
#  ('letting', 2),
#  ('books', 1),
#  ('select', 1),
#  ('co', 1),
#  ('goes', 1),
#  ('mark', 1),
#  ('anything', 1),
#  ('night', 1),
#  ('returnexchange', 1),
#  ('bringing', 2),
#  ('page', 1),
#  ('investigate', 1),
#  ('close', 1),
#  ('click', 1),
#  ('quickly', 1),
#  ('regarding', 1),
#  ('issues', 1),
#  ('hasnt', 1),
#  ('steps', 4),
#  ('qualify', 1),
#  ('atoz', 1),
#  ('claim', 1),
#  ('sb', 1),
#  ('give', 1),
#  ('other', 1),
#  ('reported', 1),
#  ('looked', 1),
#  ('text', 2),
#  ('shopping', 3),
#  ('experience', 9),
#  ('reply', 2),
#  ('to', 64),
#  ('complaints', 1),
#  ('for', 50),
#  ('post', 1),
#  ('guarantee', 3),
#  ('date', 5),
#  ('aim', 2),
#  ('deliver', 4),
#  ('by', 8),
#  ('the', 65),
#  ('given', 1),
#  ('your', 33),
#  ('email', 5),
#  ('missed', 1),
#  ('that', 18),
#  ('any', 8),
#  ('nf', 1),
#  ('sorry', 21),
#  ('please', 20),
#  ('reach', 3),
#  ('so', 18),
#  ('can', 26),
#  ('jo', 6),
#  ('you', 60),
#  ('what', 5),
#  ('add', 1),
#  ('halloween', 1),
#  ('happy', 5),
#  ('birthday', 2),
#  ('knooow', 1),
#  ('ep', 1),
#  ('awww', 1),
#  ('dont', 5),
#  ('a', 24),
#  ('day', 4),
#  ('over', 1),
#  ('on', 14),
#  ('here', 32),
#  ('surprise', 1),
#  ('rs', 2),
#  ('hi', 14),
#  ('moment', 1),
#  ('with', 6),
#  ('yp', 2),
#  ('keep', 7),
#  ('posted', 6),
#  ('and', 17),
#  ('if', 22),
#  ('it', 17),
#  ('doesnt', 5),
#  ('contact', 11),
#  ('well', 9),
#  ('bad', 2),
#  ('request', 4),
#  ('return', 3),
#  ('link', 6),
#  ('provided', 3),
#  ('sh', 6),
#  ('hey', 10),
#  ('glad', 3),
#  ('issue', 2),
#  ('has', 3),
#  ('been', 2),
#  ('resolved', 1),
#  ('from', 2),
#  ('how', 3),
#  ('report', 2),
#  ('its', 3),
#  ('not', 4),
#  ('cl', 2),
#  ('wrong', 2),
#  ('case', 2),
#  ('being', 1),
#  ('or', 4),
#  ('thirdparty', 2),
#  ('seller', 5),
#  ('our', 10),
#  ('they', 1),
#  ('direct', 1),
#  ('number', 1),
#  ('were', 9),
#  ('pls', 3),
#  ('did', 1),
#  ('order', 10),
#  ('directly', 1),
#  ('need', 4),
#  ('download', 1),
#  ('video', 2),
#  ('app', 6),
#  ('which', 1),
#  ('separate', 1),
#  ('better', 3),
#  ('soon', 2),
#  ('much', 2),
#  ('be', 8),
#  ('fun', 1),
#  ('refunds', 1),
#  ('credit', 1),
#  ('within', 1),
#  ('35', 1),
#  ('whats', 1),
#  ('expected', 1),
#  ('status', 2),
#  ('up', 2),
#  ('ak', 1),
#  ('about', 4),
#  ('access', 3),
#  ('through', 3),
#  ('twitter', 2),
#  ('review', 4),
#  ('arrived', 3),
#  ('youd', 2),
#  ('exchange', 1),
#  ('find', 2),
#  ('damaged', 1),
#  ('returnreplacement', 1),
#  ('helpep', 1),
#  ('arrange', 1),
#  ('most', 3),
#  ('see', 3),
#  ('info', 4),
#  ('cj', 2),
#  ('scan', 3),
#  ('indicates', 1),
#  ('should', 2),
#  ('arent', 1),
#  ('contacting', 1),
#  ('will', 6),
#  ('error', 1),
#  ('while', 2),
#  ('redeeming', 1),
#  ('rw', 1),
#  ('time', 3),
#  ('unable', 2),
#  ('mpos', 1),
#  ('device', 1),
#  ('cod', 1),
#  ('13', 2),
#  ('want', 2),
#  ('customers', 1),
#  ('create', 1),
#  ('replacement', 1),
#  ('stock', 2),
#  ('same', 1),
#  ('place', 1),
#  ('23', 1),
#  ('isnt', 2),
#  ('repeated', 1),
#  ('aw', 1),
#  ('prime', 1),
#  ('stay', 1),
#  ('tuned', 1),
#  ('bingewatch', 1),
#  ('me', 3),
#  ('next', 1),
#  ('thank', 1),
#  ('windows', 1),
#  ('application', 1),
#  ('available', 2),
#  ('encourage', 1),
#  ('amazonin', 1),
#  ('shopping23sr', 1),
#  ('features', 1),
#  ('33sr', 1),
#  ('concerned', 1),
#  ('some', 2),
#  ('real', 1),
#  ('td', 1),
#  ('received', 1),
#  ('shall', 1),
#  ('kindle', 3),
#  ('teams', 2),
#  ('assist', 2),
#  ('hg', 2),
#  ('ctrl', 1),
#  ('f', 1),
#  ('address', 1),
#  ('went', 1),
#  ('could', 1),
#  ('elaborate', 1),
#  ('get', 3),
#  ('kindly', 1),
#  ('drop', 1),
#  ('shared', 1),
#  ('earlier', 2),
#  ('asked', 1),
#  ('didnt', 1),
#  ('receive', 1),
#  ('reviews', 1),
#  ('written', 1),
#  ('purchased', 1),
#  ('cant', 2),
#  ('product', 1),
#  ('packages', 1),
#  ('ja', 3),
#  ('pm', 1),
#  ('then', 3),
#  ('wj', 4),
#  ('shoutout', 1),
#  ('knowing', 1),
#  ('helped', 1),
#  ('updated', 1),
#  ('sorted', 2),
#  ('ae', 3),
#  ('manage', 2),
#  ('menu', 1),
#  ('hope', 3),
#  ('helps', 3),
#  ('packaging', 1),
#  ('submit', 1),
#  ('amp', 1),
#  ('picture', 1),
#  ('spotify', 1),
#  ('alexa', 1),
#  ('checking', 1),
#  ('media', 1),
#  ('thats', 2),
#  ('back', 1),
#  ('frustrating', 1),
#  ('reading', 1),
#  ('lg', 1),
#  ('pawsome', 1),
#  ('supervisor', 1),
#  ('colleagues', 1),
#  ('off', 1),
#  ('still', 1),
#  ('modify', 1),
#  ('method', 1),
#  ('2100', 1),
#  ('vs', 1),
#  ('great', 2),
#  ('evening', 1),
#  ('accttypically', 1),
#  ('else', 1),
#  ('yourself', 1),
#  ('phonechat', 1),
#  ('attention', 2),
#  ('list', 1),
#  ('recent', 1),
#  ('location', 1),
#  ('cleared', 1),
#  ('customs', 1),
#  ('view', 1),
#  ('ship', 1),
#  ('fitbit', 1),
#  ('arrives', 1),
#  ('information', 1),
#  ('rm', 1),
#  ('cancel', 1),
#  ('membership', 1),
#  ('found', 1),
#  ('36hrs', 1),
#  ('ive', 1),
#  ('had', 1),
#  ('internally', 1),
#  ('patience', 1),
#  ('hk', 1)]

# %%
# printing count of words in descending order
word_count.sort(key=lambda x:x[1], reverse=True)
print(word_count)
# Out:
# [('the', 65), ('to', 64), ('you', 60), ('for', 50), ('your', 33), ('here', 32), ('us', 28), ('this', 27), ('can', 26), ('a', 24), ('we', 23), ('if', 22), ('sorry', 21), ('please', 20), ('have', 18), ('that', 18), ('so', 18), ('and', 17), ('it', 17), ('on', 14), ('hi', 14), ('im', 13), ('know', 13), ('is', 13), ('in', 12), ('thanks', 11), ('contact', 11), ('hey', 10), ('our', 10), ('order', 10), ('i', 9), ('experience', 9), ('well', 9), ('were', 9), ('help', 8), ('by', 8), ('any', 8), ('be', 8), ('look', 7), ('like', 7), ('let', 7), ('an', 7), ('feedback', 7), ('keep', 7), ('delivery', 6), ('out', 6), ('into', 6), ('details', 6), ('arrive', 6), ('amazon', 6), ('sj', 6), ('at', 6), ('jo', 6), ('with', 6), ('posted', 6), ('link', 6), ('sh', 6), ('app', 6), ('will', 6), ('no', 5), ('tracking', 5), ('wed', 5), ('when', 5), ('item', 5), ('further', 5), ('was', 5), ('date', 5), ('email', 5), ('what', 5), ('happy', 5), ('dont', 5), ('doesnt', 5), ('seller', 5), ('hear', 4), ('as', 4), ('do', 4), ('via', 4), ('feel', 4), ('sure', 4), ('these', 4), ('hb', 4), ('steps', 4), ('deliver', 4), ('day', 4), ('request', 4), ('not', 4), ('or', 4), ('need', 4), ('about', 4), ('review', 4), ('info', 4), ('wj', 4), ('always', 3), ('options', 3), ('now', 3), ('site', 3), ('ar', 3), ('new', 3), ('updates', 3), ('of', 3), ('leave', 3), ('but', 3), ('more', 3), ('support', 3), ('able', 3), ('try', 3), ('trouble', 3), ('gl', 3), ('shopping', 3), ('guarantee', 3), ('reach', 3), ('return', 3), ('provided', 3), ('glad', 3), ('has', 3), ('how', 3), ('its', 3), ('pls', 3), ('better', 3), ('access', 3), ('through', 3), ('arrived', 3), ('most', 3), ('see', 3), ('scan', 3), ('time', 3), ('me', 3), ('kindle', 3), ('get', 3), ('ja', 3), ('then', 3), ('ae', 3), ('hope', 3), ('helps', 3), ('update', 2), ('year', 2), ('bv', 2), ('pass', 2), ('tomorrow', 2), ('apologies', 2), ('using', 2), ('above', 2), ('looking', 2), ('late', 2), ('af', 2), ('rather', 2), ('delivering', 2), ('card', 2), ('typically', 2), ('business', 2), ('refund', 2), ('requested', 2), ('en', 2), ('account', 2), ('youre', 2), ('department', 2), ('there', 2), ('getting', 2), ('payment', 2), ('truly', 2), ('make', 2), ('inconvenience', 2), ('sr', 2), ('enjoying', 2), ('interest', 2), ('phone', 2), ('visit', 2), ('where', 2), ('customer', 2), ('free', 2), ('team', 2), ('way', 2), ('12', 2), ('are', 2), ('22', 2), ('contacted', 2), ('following', 2), ('until', 2), ('may', 2), ('alerts', 2), ('tm', 2), ('questions', 2), ('letting', 2), ('bringing', 2), ('text', 2), ('reply', 2), ('aim', 2), ('birthday', 2), ('rs', 2), ('yp', 2), ('bad', 2), ('issue', 2), ('been', 2), ('from', 2), ('report', 2), ('cl', 2), ('wrong', 2), ('case', 2), ('thirdparty', 2), ('video', 2), ('soon', 2), ('much', 2), ('status', 2), ('up', 2), ('twitter', 2), ('youd', 2), ('find', 2), ('cj', 2), ('should', 2), ('while', 2), ('unable', 2), ('13', 2), ('want', 2), ('stock', 2), ('isnt', 2), ('available', 2), ('some', 2), ('teams', 2), ('assist', 2), ('hg', 2), ('earlier', 2), ('cant', 2), ('sorted', 2), ('manage', 2), ('thats', 2), ('great', 2), ('attention', 2), ('worst', 1), ('service', 1), ('substantial', 1), ('1', 1), ('week', 1), ('confirmation', 1), ('oh', 1), ('sounds', 1), ('playlist', 1), ('matt', 1), ('fancy', 1), ('already', 1), ('20', 1), ('lil', 1), ('connect', 1), ('incorrect', 1), ('concerns', 1), ('ca', 1), ('heres', 1), ('identify', 1), ('shout', 1), ('sent', 1), ('fulfilled', 1), ('improve', 1), ('share', 1), ('specific', 1), ('form', 1), ('delay', 1), ('indicate', 1), ('check', 1), ('below', 1), ('pk', 1), ('end', 1), ('est', 1), ('checkout', 1), ('athena', 1), ('things', 1), ('than', 1), ('cold', 1), ('medicine', 1), ('am', 1), ('process', 1), ('days', 1), ('showing', 1), ('flagging', 1), ('reviewed', 1), ('earliest', 1), ('waiting', 1), ('doug', 1), ('returns', 1), ('items', 1), ('online', 1), ('shipment', 1), ('transit', 1), ('destination', 1), ('edd', 1), ('promised', 1), ('seeing', 1), ('advise', 1), ('forward ...

# %%
# Converting count of words to DF and writting to local file as .csv

import pandas as pd
df_word_count = pd.DataFrame(word_count, columns =['Word', 'Count'])
df_word_count.to_csv('count_of_words.csv')
df_word_count
# Out:
#            Word  Count
# 0           the     65
# 1            to     64
# 2           you     60
# 3           for     50
# 4          your     33
# ..          ...    ...
# 527         ive      1
# 528         had      1
# 529  internally      1
# 530    patience      1
# 531          hk      1
#
# [532 rows x 2 columns]

# %%
############################################################################################################################
# TASK 2
###########################################################################################################################

df_ft =spark.read.format("csv").option("header",True).load("find_text.csv")
print('No. of rows in find_text:',df_ft.count())
df_ft.show(10)
# Out:
# No. of rows in find_text: 53927
# +--------------------+----+
# |              id_str|text|
# +--------------------+----+
# |'793270689780203520'|null|
# |'793281386912354304'|null|
# |'793299404975247360'|null|
# |'793301295255945216'|null|
# |'793315815411978240'|null|
# |'793322306848292864'|null|
# |'793322433625415680'|null|
# |'793365409047023616'|null|
# |'793369654878232577'|null|
# |'793375905280393216'|null|
# +--------------------+----+
# only showing top 10 rows

# %%
# We need to fill in the 'text' column

df.createOrReplaceTempView("amazon_tweets")
df_ft.createOrReplaceTempView("to_find")
df_final=spark.sql("select f.id_str,text_ from amazon_tweets t inner join to_find f on t.id_str=f.id_str")
df_final.show(10)
# Out:
# +--------------------+--------------------+
# |              id_str|               text_|
# +--------------------+--------------------+
# |'793270689780203520'|@AmazonHelp Can y...|
# |'793281386912354304'|@SeanEPanjab I'm ...|
# |'793501578766319616'|@AmazonHelp It wa...|
# |'793501657346682880'|@AmazonHelp I am ...|
# |'793502854459879424'|@SeanEPanjab Plea...|
# |'793504235400884224'|@SeanEPanjab With...|
# |'793511847899070465'|@AmazonHelp It wa...|
# |'793511899279208449'|@AmazonHelp if it...|
# |'793513446633533440'|@SeanEPanjab I'm ...|
# |'793299404975247360'|@JeffBezos @amazo...|
# +--------------------+--------------------+
# only showing top 10 rows

# %%
# writting the results to local file
df_final.write.csv('find_text_filled',header=True)
